# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

movie_topic_11_new = pd.read_pickle('movie_topic_11_new.pkl')
scene_topic_11_new = pd.read_pickle('doc_topic_nmf_11_new.pkl')

# %%
#save to csv for tableau
movie_topic_11_new.to_csv('movie_topic_11_new.csv')
scene_topic_11_new.to_csv('scene_topic_11_new.csv')

# %%
pd.set_option('display.max_rows',None)
movie_topic_11_new
# Out:
#                                      Sports/mix  Horror/intense  Comedy/drama  \
# 127-Hours                               1.61432         3.16389       0.06059
# Airplane                                1.61634         1.72889       0.03092
# Aliens                                  1.00380         4.01753       0.04492
# American-History-X                      1.57761         2.87962       0.29976
# American-Pie                            2.62299         1.53112       0.18700
# American-Psycho                         1.77416         2.11526       0.14357
# Apocalypse-Now                          2.53566         3.31641       0.04963
# Big                                     1.33293         0.32278       0.09810
# Big-Lebowski,-The                       1.02088         1.77853       0.12034
# Big-Sick,-The                           2.10101         0.62998       0.23254
# Blind-Side,-The                         2.10092         1.80205       9.38882
# ...

# %%
# Out:
#                    Sports/mix  Horror/intense  Comedy/drama  War/action  \
# Final-Destination     0.70437         2.63323       0.08631     0.06421
#
#                    Combat_any_genre  Rom_com/drama  Epic/fantasy  \
# Final-Destination           0.10807        0.75962      12.23591
#
#                    Plot_Heavy/crime  Drama/mixed  Friendly_comedy/drama  \
# Final-Destination           0.47009      0.33218                0.50171
#
#                    mixed/comedy
# Final-Destination       0.54557

# %%
scene_topic_11.head()
# Out:
#        Sports/mix  Horror/intense  Comedy/drama  War/action  Combat_any_genre  \
# Joker     0.03916         0.02461       0.00149     0.00176           0.00342
# Joker     0.02903         0.01030       0.00000     0.00000           0.00205
# Joker     0.03133         0.01893       0.00028     0.00000           0.00000
# Joker     0.02447         0.02928       0.00123     0.00010           0.00000
# Joker     0.05446         0.04016       0.00291     0.00000           0.00246
#
#        Rom_com/drama  Epic/fantasy  Plot_Heavy/crime  Drama/mixed  \
# Joker        0.00000       0.00000           0.02270      0.00000
# Joker        0.00770       0.00272           0.00000      0.00000
# Joker        0.00974       0.00000           0.00000      0.01613
# Joker        0.01418       0.00000           0.00398      0.00133
# Joker        0.00000       0.00000           0.02243      0.00000
#
#        Friendly_comedy/drama  mixed/comedy
# Joker                0.00000       0.00000
# ...

# %%
# scenes and scores for just one movie

joker_scenes = scene_topic_11_new.loc[['Joker'],:] #scores, y axis. maybe select just import categoryies.

scenes = ["Joker"+str(i) for i in range(1,len(nemo_scenes.index)+1)] #scenes numbered, x axis

# %%
nemo_scenes.index = scenes

# %%
scene_topic_11.columns
# Out:
# Index(['Sports/mix', 'Horror/intense', 'Comedy/drama', 'War/action',
#        'Combat_any_genre', 'Rom_com/drama', 'Epic/fantasy', 'Plot_Heavy/crime',
#        'Drama/mixed', 'Friendly_comedy/drama', 'mixed/comedy'],
#       dtype='object')

# %%
nemo_scenes.to_csv('nemo_scenes_11_new.csv')

# %%
# library
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
# Your x and y axis
x=scenes
#y=list(joker_scenes['Comedy/drama'])
y=[ list(nemo_scenes['Combat_any_genre']),
   list(nemo_scenes['Plot_Heavy/crime']),
  list(nemo_scenes['Horror/intense'])]
 
# create your palette
plt.figure(figsize=(20,9))
sns.set(font_scale=1.3)
sns.set_style("white")

pal = ["#9b59b6", "#e74c3c", "#34495e", "#2ecc71"]
plt.stackplot(x,y, labels=['Friendly_comedy/drama','mixed/comedy', 'Comedy'], colors=pal, alpha=0.4 )
plt.legend(loc='upper right')
plt.xticks(rotation=90)
plt.title('Joker')

plt.show()

# %%
# RADAR - Pick two very different movies

# Libraries
import matplotlib.pyplot as plt
import pandas as pd
from math import pi
 
# Set data
df2 = pd.DataFrame({
'group': ['A','B','C','D'],
'var1': [38, 1.5, 30, 4],
'var2': [29, 10, 9, 34],
'var3': [8, 39, 23, 24],
'var4': [7, 31, 33, 14],
'var5': [28, 15, 32, 14]
})

# %%
df = movie_topic_11_new
df = df.iloc[[52,41], :]
df['group'] = df.index

cols_new = ['group','Sports/mix', 'Horror/intense', 'Comedy/drama', 'War/action',
       'Combat_any_genre', 'Rom_com/drama', 'Epic/fantasy', 'Plot_Heavy/crime',
       'Drama/mixed', 'Friendly_comedy/drama', 'mixed/comedy']

df = df[cols_new]

df.index = [i for i in range(0,df.shape[0])]
# Out:
# /Users/samuelouimet/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.columns
# Out:
# Index(['group', 'Sports/mix', 'Horror/intense', 'Comedy/drama', 'War/action',
#        'Combat_any_genre', 'Rom_com/drama', 'Epic/fantasy', 'Plot_Heavy/crime',
#        'Drama/mixed', 'Friendly_comedy/drama', 'mixed/comedy'],
#       dtype='object')

# %%
df.head()
# Out:
#                  group  Sports/mix  Horror/intense  Comedy/drama  War/action  \
# 0         Pianist,-The     1.36133         2.73632       0.10811     4.90141
# 1  Little-Mermaid,-The     1.53221         0.75581       0.08335     0.06914
#
#    Combat_any_genre  Rom_com/drama  Epic/fantasy  Plot_Heavy/crime  \
# 0           0.21701        0.66339       0.05514           1.61878
# 1           0.06241        1.36490       0.15336           0.68952
#
#    Drama/mixed  Friendly_comedy/drama  mixed/comedy
# 0      0.68167                0.67681       0.97107
# 1      0.74776                1.84034       1.27597

# %%
#  
    
# ------- PART 1: Create background
plt.figure(figsize=(12,9))
    
# number of variable
categories=list(df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([0,1,2,3,5], ["0","1","2","3","5"], color="grey", size=7)
plt.ylim(0,3)
 
# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="The Pianist")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="The Little Mermaid")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# %%
movie_topic_11_new.iloc[[24],:]

# %%
movie_topic_11_new.iloc[[22, 62],:]
# Out:
#                  Sports/mix  Horror/intense  Comedy/drama  War/action  \
# Friday-the-13th     2.02983         4.05317       0.09291     0.03505
# Superbad            1.21241         1.25168       8.61442     0.02460
#
#                  Combat_any_genre  Rom_com/drama  Epic/fantasy  \
# Friday-the-13th           0.11197        0.45909       0.45404
# Superbad                  2.98689        1.64969       0.01522
#
#                  Plot_Heavy/crime  Drama/mixed  Friendly_comedy/drama  \
# Friday-the-13th           0.43292      0.62853                0.74337
# Superbad                  0.82633      0.90007                2.77740
#
#                  mixed/comedy
# Friday-the-13th       1.03706
# Superbad              1.55581

# %%
sns.set()

df = movie_topic_11_new
df = df.iloc[[22, 62],:]
df['group'] = df.index

cols_new = ['group','Sports/mix', 'Horror/intense', 'Comedy/drama', 'War/action',
       'Combat_any_genre', 'Rom_com/drama', 'Epic/fantasy', 'Plot_Heavy/crime',
       'Drama/mixed', 'Friendly_comedy/drama', 'mixed/comedy']

df = df[cols_new]

df.index = [i for i in range(0,df.shape[0])]

# ------- PART 1: Create background
plt.figure(figsize=(12,9))
    
# number of variable
categories=list(df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels labels yet
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks([0,3,6], ["0","3","6"], color="grey", size=7)
plt.ylim(0,6)
 
# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't do a loop, because plotting more than 3 groups makes the chart unreadable
 
# Ind1
values=df.loc[0].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Friday the 13th")
ax.fill(angles, values, 'b', alpha=0.1)
 
# Ind2
values=df.loc[1].drop('group').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Superbad")
ax.fill(angles, values, 'r', alpha=0.1)
 
# Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
# Out:
# /Users/samuelouimet/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
movie_topic_11_new.head()
# Out:
#                     Sports/mix  Horror/intense  Comedy/drama  War/action  \
# 127-Hours              1.61432         3.16389       0.06059     0.02700
# Airplane               1.61634         1.72889       0.03092     0.13767
# Aliens                 1.00380         4.01753       0.04492     0.15334
# American-History-X     1.57761         2.87962       0.29976     0.06575
# American-Pie           2.62299         1.53112       0.18700     0.05306
#
#                     Combat_any_genre  Rom_com/drama  Epic/fantasy  \
# 127-Hours                    0.09650        0.47626       0.69443
# Airplane                     0.21521        1.28184       0.29575
# Aliens                       0.21745        0.66690       0.73185
# American-History-X           0.13734        1.27531       0.24815
# American-Pie                 0.11865        1.76146       0.08676
#
#                     Plot_Heavy/crime  Drama/mixed  Friendly_comedy/drama  \
# ...

# %%
movie_topic_11_new['title'] = movie_topic_11_new.index

# %%
piano = movie_topic_11_new.loc[movie_topic_11_new['title'] == 'Pianist,-The'].drop('title', axis=1).values.flatten().tolist()
mermaid = movie_topic_11_new.loc[movie_topic_11_new['title'] == 'Little-Mermaid,-The'].drop('title', axis=1).values.flatten().tolist()
superbad = movie_topic_11_new.loc[movie_topic_11_new['title'] == 'Finding-Nemo'].drop('title', axis=1).values.flatten().tolist()
friday = movie_topic_11_new.loc[movie_topic_11_new['title'] == 'Friday-the-13th'].drop('title', axis=1).values.flatten().tolist()

# %%
piano
# Out:
# [1.36133,
#  2.7363199999999996,
#  0.10811000000000001,
#  4.901409999999999,
#  0.21700999999999998,
#  0.6633899999999999,
#  0.05514000000000001,
#  1.6187800000000003,
#  0.6816700000000001,
#  0.6768100000000002,
#  0.9710700000000004]

# %%
import plotly.graph_objects as go

categories = list(movie_topic_11_new.columns)

fig = go.Figure()

fig.add_trace(go.Scatterpolar(
      r=superbad,
      theta=categories,
      fill='toself',
      name='Superbad'
))
fig.add_trace(go.Scatterpolar(
      r=friday,
      theta=categories,
      fill='toself',
      name='Friday the 13th'
))

fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 5]
    )),
  showlegend=True
)

fig.show()
# Out:
# <div>
#
#
#             <div id="b9060afe-b933-4f05-bed4-4adcd39e3335" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b9060afe-b933-4f05-bed4-4adcd39e3335")) {
#                     Plotly.newPlot(
#                         'b9060afe-b933-4f05-bed4-4adcd39e3335',
# ...
